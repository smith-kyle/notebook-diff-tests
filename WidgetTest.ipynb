# %% [markdown]
# # Instructions
#
# 1. Run the two cells below. Go ahead and make sure that the notebook is trusted and that "Save Widget State Automatically" is checked in the Settings menu.
# 2. Save this notebook, close it and shut down the kernel.
# 3. Open this notebook a second time. Don't change a thing. Just make sure that the Text widget renders from the model appropriately. Great!
# 4. Save the notebook again. Close it and shut down the kernel.
# 5. Open the notebook a third time. Watch as the cell with the widget displays: "Error displaying widget: model not found".

# %%
import ipywidgets

# %%
ipywidgets.Text()
# Out:
# Text(value='')
